# %%
import random
list=[]
for x in range(65,91):
    a=str(chr(x))
    list.append(a)
for x in range(97,123):
    a=str(chr(x))
    list.append(a)
for x in range(0,10):
    a=str(x)
    list.append(a)
def code():
    a=random.sample(list,16)
    print(a)
for x in range(0,200):
    code()
# Out:
# ['D', 'f', 'O', 'R', 'p', 'd', 'Y', 'L', 'v', 'T', 'V', 'i', 't', 'X', 'G', 'E']
# ['V', 'q', 'S', '4', 'u', 'i', 'P', 'F', 'G', 'y', 'D', '9', 'c', 'N', 'p', '8']
# ['0', 'G', 'f', '4', 's', 'Z', 'p', 'S', 'H', 'C', '2', 'D', 'E', '9', 'x', 't']
# ['c', 'q', 'P', 'l', 'X', 'h', 'G', 'J', 'a', 'W', 'N', 'i', 'g', 'B', 'k', 'T']
# ['g', 'A', 'Z', '9', 'H', 'N', 'M', 'f', 'e', 'q', 'p', 'y', 'j', 't', '7', 'x']
# ['U', '3', 'a', 'T', 'R', 'J', 'n', 'L', 'X', 'b', 'K', '8', '2', 'q', 'u', 'F']
# ['F', '8', 'z', 'B', 'i', 'R', 'O', 'r', 'p', 'h', 'Z', 'g', 'Q', 'v', 'I', '2']
# ['e', '5', 'R', 'g', 'y', 'I', 'K', '2', 'T', 'E', 'Y', 'M', 'r', 'm', '1', 'S']
# ['3', 'O', 'b', 'f', 'X', '6', 'S', 's', 'W', 'h', '1', 'w', 'Q', 'V', 'I', 'Z']
# ['m', 't', 'F', '3', 'l', '5', '2', 'a', 'c', '6', 'I', '1', 's', 'y', 'f', 'x']
# ['W', 'a', 'd', 't', 'E', 'c', 'w', 'x', 'z', '1', '8', 'P', 'i', '6', 'g', 'F']
# ['v', 'K', 't', 'c', 'O', 'I', 'l', 'F', 'C', 'N', 'D', 'X', '3', 'a', 'W', 'R']
# ...
